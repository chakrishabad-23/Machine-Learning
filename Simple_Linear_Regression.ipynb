# %% [markdown]
# <a href="https://colab.research.google.com/github/chakrishabad-23/Machine-Learning/blob/main/Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("placement.csv")
print(df)
x=df.iloc[:,0]
y=df.iloc[:,1]
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
x_train=x_train.values.reshape(-1,1)
y_train=y_train.values.reshape(-1,1)
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.predict(x_test.values.reshape(-1,1)))
# Out:
# [[3.89111601]
#  [3.09324469]
#  [2.38464568]
#  [2.57434935]
#  [1.6537286 ]
#  [1.77647803]
#  [2.07219258]
#  [2.93143862]
#  [3.76278706]
#  [2.93701814]
#  [4.09197872]
#  [3.51170867]
#  [2.97049525]
#  [2.40138424]
#  [3.18809652]
#  [3.46707251]
#  [1.94386362]
#  [3.24389172]
#  [2.97607477]
#  [3.41685683]
#  [2.55761079]
#  [3.16577844]
#  [2.85890486]
#  [3.12114229]
#  [3.68467378]
#  [2.8700639 ]
#  [3.49497011]
#  [3.34432308]
#  [3.91901361]
#  [1.96060218]
#  [3.65119666]
#  [3.2104146 ]
#  [3.74046898]
#  [2.7863711 ]
#  [2.78079158]
#  [3.27178932]
#  [3.52844723]
#  [2.61340599]
#  [2.65804215]
#  [2.71383735]]

# %%
y_pred=lr.predict(x_test.values.reshape(-1,1))
y_test=y_test
y_pred = lr.predict(x_test.values.reshape(-1, 1))
y_test = y_test  # already a NumPy array

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
print(mean_absolute_error(y_pred,y_test))
print(mean_squared_error(y_pred,y_test))
r2=r2_score(y_test,y_pred)
print(r2_score(y_test,y_pred))
print((1-(((1-r2)*(len(y_test)-1))/(len(y_test)-2))))
# Out:
# 0.2884710931878175
# 0.12129235313495527
# 0.780730147510384
# 0.7749598882343415

# %%
from sklearn.datasets import make_regression
x,y=make_regression(n_samples=1000, n_features=2)

# %%
lr=LinearRegression()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(x_test[0].reshape(-1,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-4dcb472c1ea0> in <cell line: 0>()
# ----> 1 lr.predict(x_test[0].reshape(-1,1))
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     295             Returns predicted values.
#     296         """
# --> 297         return self._decision_function(X)
#     298
#     299     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     274         check_is_fitted(self)
#     275
# --> 276         X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     277         coef_ = self.coef_
#     278         if coef_.ndim == 1:
#
# ...

# %%
df2=pd.read_csv("Salary_Data.csv")
print(df2)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x_train,x_test,y_train,y_test=train_test_split(df2.iloc[:,0],df2.iloc[:,1],test_size=0.2,random_state=2)

# %%
lr2=LinearRegression()

# %%
lr2.fit(x_train.values.reshape(-1,1),y_train.values.reshape(-1,1))
# Out:
# LinearRegression()

# %%
print(lr2.predict(x_test.iloc[0].reshape(-1,1)))
print(y_test.iloc[0])
# Out:
# [[36833.63210301]]
# 46205.0

# %%
print(x_test[0],y_test[0])
# Out:
# 1.1 39343.0
